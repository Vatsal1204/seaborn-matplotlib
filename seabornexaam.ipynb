# %%
print("hello sir")
# Out:
# hello sir

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("easy.csv")
sns.set(style="whitegrid")

numeric_df = df.select_dtypes(include=['int64', 'float64'])

if not numeric_df.empty:
    sns.pairplot(numeric_df)
    plt.suptitle("Pairplot of Numeric Columns", y=1.02)
    plt.show()

if not numeric_df.empty:
    corr = numeric_df.corr()
    sns.heatmap(corr, annot=True, cmap="coolwarm")
    plt.title("Correlation Heatmap")
    plt.show()

for col in numeric_df.columns:
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

for col in numeric_df.columns:
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_json("sales.json")
plt.rcParams["figure.figsize"] = (8, 5)
sns.set_style("whitegrid")

plt.figure()
sns.lineplot(x='Month', y='Sales', hue='Product', data=data, marker='o')
plt.title("1. Line Plot - Sales over Months")
plt.show()

plt.figure()
sns.barplot(x='Month', y='Sales', hue='Product', data=data)
plt.title("2. Bar Plot - Sales per Month")
plt.show()

#3
plt.figure()
sns.boxplot(x='Product', y='Sales', data=data)
plt.title("3. Box Plot - Sales by Product")
plt.show()

plt.figure()
sns.violinplot(x='Product', y='Sales', data=data)
plt.title("4. Violin Plot - Sales by Product")
plt.show()

plt.figure()
sns.stripplot(x='Month', y='Sales', hue='Product', data=data, jitter=True)
plt.title("5. Strip Plot - Sales Scatter")
plt.show()

plt.figure()
sns.swarmplot(x='Month', y='Sales', hue='Product', data=data)
plt.title("6. Swarm Plot - Sales by Month")
plt.show()

plt.figure()
sns.histplot(data=data, x='Sales', hue='Product', bins=5)
plt.title("7. Histogram - Sales Distribution")
plt.show()

plt.figure()
sns.kdeplot(data=data, x='Sales', hue='Product', fill=True)
plt.title("8. KDE Plot - Sales Density")
plt.show()

plt.figure()
sns.pointplot(x='Month', y='Sales', hue='Product', data=data)
plt.title("9. Point Plot - Monthly Sales Trend")
plt.show()

plt.figure()
pivot_data = data.pivot_table(index='Product', columns='Month', values='Sales')
sns.heatmap(pivot_data, annot=True, cmap='Blues')
plt.title("10. Heatmap - Sales Matrix")
plt.show()
